# %% [markdown]
# 1. Power law 參考資料: https://blog.csdn.net/kevinelstri/article/details/52685934
# 2. import power: https://pypi.org/project/powerlaw/

# %%
import numpy as np
import matplotlib.pyplot as plt
import powerlaw

# %%
path = 'ADFA-LD/Training_Data_Master/'
syslen = []
syscall = []

for i in range(1, 834):
    if (i > 0 and i < 10):
        with open(path + 'UTD-000{}.txt'.format(i)) as f:
            lines = f.readlines()
            for item in lines:
                syscall.extend(item.split())
            syslen.append(len(syscall))
            syscall = []
    
    if (i >= 10 and i < 100):
        with open(path + 'UTD-00{}.txt'.format(i)) as f:
            lines = f.readlines()
            for item in lines:
                syscall.extend(item.split())
            syslen.append(len(syscall))
            syscall = []
    
    if (i >= 100 and i < 1000):
        with open(path + 'UTD-0{}.txt'.format(i)) as f:
            lines = f.readlines()
            for item in lines:
                syscall.extend(item.split())
            syslen.append(len(syscall))
            syscall = []

print("system call length:\n", syslen, len(syslen))
# Out:
# system call length:
# ...

# %%
# calculator frequency
syslen.sort()

# plot raw data
Y = np.array(syslen)
plt.title("Train Raw Data")
plt.hist(Y, label='train data')
plt.ylabel('system call length')
plt.xlabel('count')


def DataVisualization():
    # 繪製 log-log plot
    pass

# find powerlaw
results = powerlaw.Fit(Y)
results.power_law.plot_pdf( color= 'b',linestyle='--',label='fit ccdf')
results.plot_pdf( color= 'b')
print("alpha:", results.power_law.alpha)
print("Xmin:", results.power_law.xmin)
R, p = results.distribution_compare('power_law', 'lognormal')
# Out:
# Calculating best minimal value for power law fit
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# alpha: 2.0814025200058657
# Xmin: 137.0
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.

# %%
path = 'Validation_Data_Master/'
syslen = []
syscall = []

for i in range(1, 4373):
    if (i > 0 and i < 10):
        with open(path + 'UVD-000{}.txt'.format(i)) as f:
            lines = f.readlines()
            for item in lines:
                syscall.extend(item.split())
            syslen.append(len(syscall))
            syscall = []
    
    if (i >= 10 and i < 100):
        with open(path + 'UVD-00{}.txt'.format(i)) as f:
            lines = f.readlines()
            for item in lines:
                syscall.extend(item.split())
            syslen.append(len(syscall))
            syscall = []
    
    if (i >= 100 and i < 1000):
        with open(path + 'UVD-0{}.txt'.format(i)) as f:
            lines = f.readlines()
            for item in lines:
                syscall.extend(item.split())
            syslen.append(len(syscall))
            syscall = []
            
    if (i >= 1000 and i < 10000):
        with open(path + 'UVD-{}.txt'.format(i)) as f:
            lines = f.readlines()
            for item in lines:
                syscall.extend(item.split())
            syslen.append(len(syscall))
            syscall = []
            
print("system call length:\n", syslen, len(syslen))
# Out:
# system call length:
# ...

# %%
# calculator frequency
syslen.sort()

# plot raw data
Y = np.array(syslen)
plt.title("Validation Raw Data")
plt.hist(Y, label='validation data')
plt.ylabel('system call length')
plt.xlabel('count')

def DataVisualization():
    # 繪製 log-log plot
    Y_log = np.log10(Y)
    plt.hist(Y_log)
    print(Y_log, len(Y_log))
    
    pass

DataVisualization()
# Out:
# [1.89762709 1.91381385 1.91907809 1.92941893 1.92941893 1.92941893
#  1.92941893 1.93449845 1.93449845 1.93449845 1.93951925 1.94448267
#  1.94448267 1.94939001 1.95424251 1.95904139 1.95904139 1.95904139
#  1.95904139 1.96378783 1.96378783 1.96378783 1.96378783 1.96848295
#  1.96848295 1.96848295 1.96848295 1.96848295 1.96848295 1.97312785
#  1.97312785 1.97312785 1.97312785 1.97312785 1.97312785 1.97772361
#  1.97772361 1.97772361 1.97772361 1.97772361 1.97772361 1.98227123
#  1.98227123 1.98677173 1.98677173 1.98677173 1.98677173 1.98677173
#  1.98677173 1.98677173 1.98677173 1.98677173 1.99122608 1.99122608
#  1.99122608 1.99122608 1.99122608 1.99122608 1.99122608 1.99563519
#  1.99563519 1.99563519 1.99563519 1.99563519 2.         2.
#  2.00432137 2.00432137 2.00860017 2.00860017 2.00860017 2.00860017
#  2.00860017 2.00860017 2.01283722 2.01283722 2.01283722 2.01283722
#  2.01703334 2.01703334 2.01703334 2.01703334 2.01703334 2.01703334
# ...

# %%
print(syslen.sort())
Y = np.array(syslen)
print(Y)
# Out:
# None
# [  79   82   83   85   85   85   85   86   86   86   87   88   88   89
#    90   91   91   91   91   92   92   92   92   93   93   93   93   93
#    93   94   94   94   94   94   94   95   95   95   95   95   95   96
#    96   97   97   97   97   97   97   97   97   97   98   98   98   98
#    98   98   98   99   99   99   99   99  100  100  101  101  102  102
#   102  102  102  102  103  103  103  103  104  104  104  104  104  104
#   105  105  105  105  106  107  107  107  107  107  108  108  109  109
#   109  109  110  110  110  110  110  110  110  110  110  110  110  110
#   110  110  110  110  110  110  110  110  110  110  111  111  111  111
#   111  111  112  113  113  113  114  115  115  115  115  115  115  115
#   116  116  116  116  116  116  116  117  117  117  117  118  118  118
#   119  119  119  119  120  120  121  121  121  121  121  121  121  122
#   122  122  122  122  122  122  123  123  124  124  124  124  124  124
# ...

# %%
Y_log = np.log10(Y)
print(Y_log)
# Out:
# [1.89762709 1.91381385 1.91907809 1.92941893 1.92941893 1.92941893
#  1.92941893 1.93449845 1.93449845 1.93449845 1.93951925 1.94448267
#  1.94448267 1.94939001 1.95424251 1.95904139 1.95904139 1.95904139
#  1.95904139 1.96378783 1.96378783 1.96378783 1.96378783 1.96848295
#  1.96848295 1.96848295 1.96848295 1.96848295 1.96848295 1.97312785
#  1.97312785 1.97312785 1.97312785 1.97312785 1.97312785 1.97772361
#  1.97772361 1.97772361 1.97772361 1.97772361 1.97772361 1.98227123
#  1.98227123 1.98677173 1.98677173 1.98677173 1.98677173 1.98677173
#  1.98677173 1.98677173 1.98677173 1.98677173 1.99122608 1.99122608
#  1.99122608 1.99122608 1.99122608 1.99122608 1.99122608 1.99563519
#  1.99563519 1.99563519 1.99563519 1.99563519 2.         2.
#  2.00432137 2.00432137 2.00860017 2.00860017 2.00860017 2.00860017
#  2.00860017 2.00860017 2.01283722 2.01283722 2.01283722 2.01283722
#  2.01703334 2.01703334 2.01703334 2.01703334 2.01703334 2.01703334
# ...

# %%
# calculator frequency
syslen.sort()

# plot raw data
Y = np.array(syslen)
plt.title("Validation Raw Data")
plt.hist(Y, label='validation data')
plt.ylabel('system call length')
plt.xlabel('count')

def DataVisualization():
    # 繪製 log-log plot
    Y_log = np.log10(Y)
    plt.hist(Y_log)
    print(Y_log, len(Y_log))
    
    pass

DataVisualization()
